# %% [markdown]
# <a href="https://colab.research.google.com/github/danianamir/Tile-Based-Level-Design/blob/main/Tile_Based_Level_Design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # dependecies

# %%
#clone git
# !git clone https://github.com/danianamir/Tile-Based-Level-Design.git
# %cd /content/Tile-Based-Level-Design
# !git pull origin main
# Out:
# Cloning into 'Tile-Based-Level-Design'...
# remote: Enumerating objects: 1320, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 1320 (delta 43), reused 18 (delta 4), pack-reused 1226
# Receiving objects: 100% (1320/1320), 173.09 MiB | 12.34 MiB/s, done.
# Resolving deltas: 100% (766/766), done.
# Updating files: 100% (620/620), done.
# /content/Tile-Based-Level-Design
# From https://github.com/danianamir/Tile-Based-Level-Design
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
#package installs with pip_github......................................................................
# %cd /content/Tile-Based-Level-Design/ml-agents-envs
# !pip install .
# !pip install gymnasium
# !pip install ray[rllib]
# Out:
# /content/Tile-Based-Level-Design/ml-agents-envs
# Processing /content/Tile-Based-Level-Design/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (2.2.1)
# Requirement already satisfied: grpcio>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (1.60.0)
# Requirement already satisfied: numpy<1.24,>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (1.23.5)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (9.4.0)
# Requirement already satisfied: protobuf>=3.6 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (3.20.3)
# Requirement already satisfied: pyyaml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (6.0.1)
# Requirement already satisfied: gym>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (0.25.2)
# Collecting pettingzoo==1.15.0 (from mlagents-envs==0.30.0)
#   Downloading PettingZoo-1.15.0.tar.gz (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.30.0) (3.13.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.21.0->mlagents-envs==0.30.0) (0.0.8)
# Building wheels for collected packages: mlagents-envs, pettingzoo
#   Building wheel for mlagents-envs (setup.py) ... done
#   Created wheel for mlagents-envs: filename=mlagents_envs-0.30.0-py3-none-any.whl size=88754 sha256=748d4af5682c7fedfd581ca8bf98221c2588ec95a692c805ee9a14c07c35f282
#   Stored in directory: /root/.cache/pip/wheels/2b/56/d7/23048fc8cc5dd066914bdd88bb14ab6ea85ce21552c480a402
#   Building wheel for pettingzoo (setup.py) ... done
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875631 sha256=61cfde7fcdc3b3db1fbfc4ba44f7a02dda918bb5930c44e20d838febc2797308
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# Successfully built mlagents-envs pettingzoo
# Installing collected packages: pettingzoo, mlagents-envs
# Successfully installed mlagents-envs-0.30.0 pettingzoo-1.15.0
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1
# Collecting ray[rllib]
#   Downloading ray-2.9.1-cp310-cp310-manylinux2014_x86_64.whl (64.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (3.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (1.0.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (23.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (1.5.3)
# Collecting tensorboardX>=1.9 (from ray[rllib])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (10.0.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (2023.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (0.1.8)
# Collecting gymnasium==0.28.1 (from ray[rllib])
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 62.2 MB/s eta 0:00:00
# Collecting lz4 (from ray[rllib])
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (1.11.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (0.9.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ray[rllib]) (13.7.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]) (1.23.5)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->ray[rllib])
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]) (0.0.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]) (0.17.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[rllib]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[rllib]) (2.16.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]) (2023.12.9)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->ray[rllib]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->ray[rllib]) (1.16.0)
# Installing collected packages: tensorboardX, lz4, jax-jumpy, gymnasium, ray
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# Successfully installed gymnasium-0.28.1 jax-jumpy-1.0.0 lz4-4.3.3 ray-2.9.1 tensorboardX-2.6.2.2

# %%
import mlagents_envs
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.base_env import ActionTuple


#gymnasium
import gymnasium as gym
from gymnasium import spaces

#ray
import ray
from ray import  tune ,train
from ray.rllib.examples.policy.random_policy import RandomPolicy
from ray.rllib.evaluation.rollout_worker import RolloutWorker
from ray.rllib.evaluation.worker_set import WorkerSet
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.rllib.algorithms.algorithm_config import AlgorithmConfig
from ray.rllib.algorithms.algorithm import Algorithm
from ray.tune.registry import register_env
from ray.rllib.policy.policy import PolicySpec
from ray.rllib.env.multi_agent_env import MultiAgentEnv
from ray.rllib.algorithms.ppo.ppo import PPOConfig
from ray.rllib.algorithms.ppo.ppo import PPO
from ray.rllib.models import ModelCatalog
from ray.rllib.models.torch.torch_modelv2 import TorchModelV2
from ray.rllib.models import MODEL_DEFAULTS
from ray.rllib.policy.rnn_sequencing import add_time_dimension
from ray.rllib.models.torch.misc import SlimFC , SlimConv2d,normc_initializer

from ray.rllib.models.torch.fcnet import  FullyConnectedNetwork
from ray.rllib.models.torch.visionnet import  VisionNetwork
from ray.rllib.models.torch.recurrent_net import LSTMWrapper

from ray.rllib.policy.policy import Policy

# torch
import torch
from torch import nn
import torch.onnx as onnx



#others
import numpy as np
import random
import time
from pprint import pprint
from typing import Any, Dict, List, Optional, Tuple, Union
import os
import time
from ray.rllib.utils.annotations import override
# Out:
# /usr/local/lib/python3.10/dist-packages/flax/configurations.py:42: DeprecationWarning: jax.config.define_bool_state is deprecated. Please use other libraries for configuration instead.
#   return jax_config.define_bool_state('flax_' + name, default, help)
# /usr/local/lib/python3.10/dist-packages/flax/linen/activation.py:36: DeprecationWarning: jax.nn.normalize is deprecated. Use jax.nn.standardize instead.
#   from jax.nn import normalize
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <

# %%
# give access to run the linux file ................................................................................
# %cd
# !chmod -R 755 /content/Tile-Based-Level-Design/unity_built_linux/my_game.x86_64
# !chmod -R 755 /content/Tile-Based-Level-Design/unity_built_linux/UnityPlayer.so
# !ls -l /content/Tile-Based-Level-Design/unity_built_linux
# Out:
# /root
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# total 116244
# drwxr-xr-x 3 root root     4096 Jan 29 11:14 my_game_BurstDebugInformation_DoNotShip
# drwxr-xr-x 6 root root     4096 Jan 29 11:14 my_game_Data
# -rw-r--r-- 1 root root    16040 Jan 29 11:14 my_game_s.debug
# -rwxr-xr-x 1 root root    15008 Jan 29 11:14 my_game.x86_64
# -rw-r--r-- 1 root root 69732336 Jan 29 11:14 UnityPlayer_s.debug
# -rwxr-xr-x 1 root root 50427088 Jan 29 11:14 UnityPlayer.so

# %%
filename_linux="/content/Tile-Based-Level-Design/unity_built_linux/my_game.x86_64"
filename_algo ="/content/Tile-Based-Level-Design/ALGO/DISCRETE_local/neg"

# %% [markdown]
# # environment

# %%
class Unity3DEnv(MultiAgentEnv):


    _BASE_PORT_EDITOR = 5004
    _BASE_PORT_ENVIRONMENT = 5005
    _WORKER_ID = 0

    def __init__(
        self,
        file_name: str = None,
        port: Optional[int] = None,
        seed: int = 0,
        no_graphics: bool = False,
        timeout_wait: int = 300,
        episode_horizon: int = None,

    ):

        self._skip_env_checking = True
        super().__init__()

        if file_name is None:
            print(
                "No game binary provided, will use a running Unity editor "
                "instead.\nMake sure you are pressing the Play (|>) button in "
                "your editor to start."
            )

        # Try connecting to the Unity3D game instance. If a port is blocked
        port_ = None
        while True:
            # Sleep for random time to allow for concurrent startup of many
            # environments (num_workers >> 1). Otherwise, would lead to port
            # conflicts sometimes.
            if port_ is not None:
                time.sleep(random.randint(1, 10))
            port_ = port or (
                self._BASE_PORT_ENVIRONMENT if file_name else self._BASE_PORT_EDITOR
            )
            # cache the worker_id and
            # increase it for the next environment
            worker_id_ = Unity3DEnv._WORKER_ID if file_name else 0
            Unity3DEnv._WORKER_ID += 1
            try:
                self.unity_env = UnityEnvironment(
                    file_name=file_name,
                    worker_id=worker_id_,
                    base_port=port_,
                    seed=seed,
                    no_graphics=no_graphics,
                    timeout_wait=timeout_wait,
                )

                print("Created UnityEnvironment for port {}".format(port_ + worker_id_))
            except mlagents_envs.exception.UnityWorkerInUseException:
                pass
            else:
                break

        self.episode_horizon = episode_horizon
        self.episode_timesteps = 0






    def step(
        self, action_dict
    ):

        # it take a action_dict {"instantiator Behaviour" : tuple(spaces.box(shape(2,)) , multidiscrete([3,4]))  , "modifyer Behavior":tuple(box(shape(2,)) , spaces.multidiscrete([6,2]))}
        # make a list called actions for each beahivor for example
        # for "instantiator Behaviour" make : action[0] = tuple(spaces.box(shape(2,)) , spaces.discrete[3])
        # for "modifyer Behavior" make : action[0] = tuple(box(shape(2,)) , spaces.multidiscrete([6,2])

        for behavior_name in self.unity_env.behavior_specs:
                actions = []
                for agent_id in self.unity_env.get_steps(behavior_name)[0].agent_id:
                    key = behavior_name + "_{}".format(agent_id)
                    actions.append(action_dict[key])



                # take the actions list of the current behavior  and make a action_tuple list for current behavior
                # action tuple is a object that contain both discrete and continious action :
                # for example for  "instantiator Behaviour" :
                #action_tuple.continous = spaces.box(shape(2,))
                #action_tuple.discret= = spaces.discrete(3)


                    #the behaviorname == actuall behaviorname in unity +team=0
                    # for action tuple we had to pass a numpy arrye with shape (<number of agents>, <action size>)
                    if behavior_name=="instantiator Behaviour?team=0":
                       x=actions[0]["element_1"]
                       multi_discrete_action=np.array([x])
                       action_tuple =ActionTuple( discrete= multi_discrete_action)





                    # pass the current behavior and its action_tuple to step() function
                    self.unity_env.set_actions(behavior_name, action_tuple)

        self.unity_env.step()
        self.episode_timesteps += 1
        obs, rewards, terminateds, truncateds, infos = self._get_step_results()
        return obs, rewards, terminateds, truncateds, infos














    def reset(
        self, *, seed=None, options=None
    ):
        self.episode_timesteps = 0
        self.unity_env.reset()
        obs, _, _, _, infos = self._get_step_results()
        return obs, infos








    def _get_step_results(self):

        # first we set the initial dict that step return
        obs = {}
        rewards = {}
        terminated ={}
        truncated={}
        infos = {}


        num_active=0
        num_done=0
        num_all=0



        #go thorugh all the behavior
        # return decision_step (batch of agent have similar behavior)
        # return trminal steps  (batch of agent have similar behavior /that end thier episode)
        for behavior_name  in self.unity_env.behavior_specs:
            decision_steps, terminal_steps = self.unity_env.get_steps(behavior_name)
            num_active=num_active+len(decision_steps)
            num_done=num_done+len(terminal_steps)
            num_all=num_active+num_done





            #set the obs / reward  from  decision step for each agent like:{"behavior_name+agent_id" : numpy array}
            for agent_id, idx in decision_steps.agent_id_to_index.items():
                key = behavior_name + "_{}".format(agent_id)
                os = tuple(o[idx] for o in decision_steps.obs)
                os = os[0] if len(os) == 1 else os
                obs[key]=  os
                rewards[key] = (decision_steps.reward[idx] )



            #set the obs / reward  from  terminal_steps for each agent like:{"behavior_name+agent_id" : numpy array}
            for agent_id, idx in terminal_steps.agent_id_to_index.items():
                key = behavior_name + "_{}".format(agent_id)
                if key not in obs:
                    os = tuple(o[idx] for o in terminal_steps.obs)
                    os = os[0] if len(os) == 1 else os
                    obs[key]=  os

                rewards[key] = (terminal_steps.reward[idx] )


            #+ decision_steps.group_reward[idx]
         #+ terminal_steps.group_reward[idx]


        #infos={"acive":num_active , "done":num_done , "all":num_all }


        # set the terminated if all agent end thier own episod like: {"__all__":True}
        if(num_active>0):
           terminated["__all__"]=False
        else:
           terminated["__all__"]=True



        # set the truncated /if the step of the env reach the horizen like{"__all__":True}
        if self.episode_timesteps == self.episode_horizon:
          truncated["__all__"]=True
        else:
          truncated["__all__"]=False


        # return
        return obs, rewards, terminated, truncated, infos

# %% [markdown]
# # register env

# %%
# register the unity env
tune.register_env("unity3d",lambda _: Unity3DEnv(file_name=filename_linux,
                                                                                 episode_horizon=100,
                                                                                    no_graphics=True,
                                                                                )
                                                )

# %% [markdown]
# # model

# %% [markdown]
# در این بخش مدل یا شبکه عصبی عامل را با استفاده از کتابخانه پایتورچ پیاده سازی کرده ایم که ۱ لایه کانولوشن  برای این که مقادیر خانه ها را در محیط که برروی ان چه نوع جعبه ای قرار دارد بررسی کند
# ههمچنین ۱ لایه کاملا متصل دارد که  مکان عامل و بردار های ویژگی در لحظه به ان داده میشود
# و در اخر انها با هم ترکیب مشوند و به عنوان خروجی اکشن مورد نظر را باز میگردانند

# %%
class mine(  TorchModelV2, nn.Module):

    def __init__(self, obs_space, action_space, num_outputs, model_config, name):
        TorchModelV2.__init__( self, obs_space, action_space, num_outputs, model_config, name)
        nn.Module.__init__(self)

        self._features=None
        self.cell_size=model_config["lstm_cell_size"]



        #conv layer
        self.conv1 =SlimConv2d(
                   in_channels=1,
                    out_channels=32,
                    kernel=2,
                    stride=1,
                    padding=1,
                    activation_fn="relu",
                )






        #fc layer
        self.fc1=SlimFC(
            in_size=8,
            out_size=64,
            initializer=normc_initializer(1.0),
            activation_fn="relu",
        )



        # fc+conv concated
        self.fc2=SlimFC(
            in_size=576,
            out_size=512,
            initializer=normc_initializer(1.0),
            activation_fn="relu",
        )



        self.fc3=SlimFC(
            in_size=512,
            out_size=256,
            initializer=normc_initializer(1.0),
            activation_fn="relu",
        )




        #logit
        self.logit =   SlimFC(
            in_size=256,
            out_size=num_outputs,
            initializer=normc_initializer(0.01),
            activation_fn=None,
        )



        # value
        self.value=SlimFC(
            in_size=256,
            out_size=1,
            activation_fn=None,
           initializer=normc_initializer(0.01),
        )



    def forward(self, input_dict, state, seq_lens):

        self.conv_input=input_dict["obs_flat"][:,:9].unsqueeze(1).reshape(input_dict["obs_flat"].shape[0], 1, 3, 3)
        self.fc_input=  input_dict["obs_flat"][:,9:].float()


        #conv
        out=  self.conv1(self.conv_input)
        conv_out= out.view(out.size(0), -1)



        #fc
        fc_out=self.fc1(self.fc_input)




        #concat
        concat= torch.cat((  fc_out, conv_out), dim=1)
        concat_out=self.fc2(concat)

        #faeture
        self._features=self.fc3(concat_out)



        # logit
        output = self.logit(self._features)



        return output , state




    def value_function(self) :
        assert  self._features is not None, "must call forward() first"
        return torch.reshape(self.value( self._features), [-1])

# %%
model = mine(obs_space=spaces.Box(float("-inf"), float("inf"), (17,)),
                                            action_space= spaces.Dict({"element_1":spaces.MultiDiscrete([3,5])}),
                                            num_outputs=9,
                                            model_config=MODEL_DEFAULTS,
                                            name="my_model")


# initialize  input_dict  , seq_lent
obs = torch.rand(6,17)
#print(obs)
input_dict={"obs_flat":obs , "obs":obs }
seq_lens=np.array([0,])

#initialize state with  get_initial_state
state = model.get_initial_state()

# initialize sate with fake state
h0=torch.rand(1,256)
c0=torch.rand(1,256)
state=[h0,c0]


# foward
out = model(
            input_dict=input_dict,
            state=state,
            seq_lens=seq_lens
           )

#print("the output is {}".format(out))

# %% [markdown]
# # register model

# %%
ModelCatalog.register_custom_model("mine", mine)

# %% [markdown]
# # train the algorithm

# %% [markdown]
# حال در این قسمت به اموزش عامل بر روی محیط داده شده با استفاده از الگوریتم میپردازیم.

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
discrete_instantiator = spaces.MultiDiscrete([3,5])





policies = { "policy_initializer":PolicySpec (
                                   observation_space= spaces.Box(float("-inf"), float("inf"), (17,)),
                                    action_space=spaces.Dict({"element_1":discrete_instantiator}),
                                    config={}
                                                                )


                }





def policy_mapping_fn(agent_id, episode, worker, **kwargs):
    if agent_id == 'instantiator Behaviour?team=0_0':
        return "policy_initializer"
    if agent_id =='modifyer Behavior?team=0_1':
        return "policy_modifier"





config=(
    PPOConfig()
    .environment("unity3d")

    .multi_agent(
                        policies=policies,
                         policy_mapping_fn=policy_mapping_fn
                        )

    .framework("torch")

    .rollouts(
            num_rollout_workers=2,

                )

    .resources(num_gpus=1)

    .training(
            lr=0.001,
            lambda_=0.95,
            gamma=0.99,
            sgd_minibatch_size=512,
            train_batch_size=10000,
            num_sgd_iter=30,
            clip_param=0.2,
            entropy_coeff=0,
            model={
                   "custom_model": "mine",
                    "custom_model_config": {},

                   },


            )
    .evaluation()
    .experimental(_enable_new_api_stack=False)
    .checkpointing(export_native_model_files=True)

    )

for key , item in config.items():
    print(key +":{}".format( item) )
# Out:
# extra_python_environs_for_driver:{}
# extra_python_environs_for_worker:{}
# num_gpus:1
# num_cpus_per_worker:1
# num_gpus_per_worker:0
# _fake_gpus:False
# num_learner_workers:0
# num_gpus_per_learner_worker:0
# num_cpus_per_learner_worker:1
# local_gpu_idx:0
# custom_resources_per_worker:{}
# placement_strategy:PACK
# eager_tracing:True
# eager_max_retraces:20
# tf_session_args:{'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}
# local_tf_session_args:{'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}
# torch_compile_learner:False
# torch_compile_learner_what_to_compile:forward_train
# torch_compile_learner_dynamo_backend:inductor
# torch_compile_learner_dynamo_mode:None
# torch_compile_worker:False
# torch_compile_worker_dynamo_backend:onnxrt
# torch_compile_worker_dynamo_mode:None
# env:unity3d
# env_config:{}
# observation_space:None
# action_space:None
# env_task_fn:None
# render_env:False
# clip_rewards:None
# normalize_actions:True
# clip_actions:False
# disable_env_checking:False
# auto_wrap_old_gym_envs:True
# action_mask_key:action_mask
# _is_atari:None
# env_runner_cls:None
# num_envs_per_worker:1
# enable_connectors:True
# rollout_fragment_length:auto
# batch_mode:truncate_episodes
# validate_workers_after_construction:True
# compress_observations:False
# sampler_perf_stats_ema_coef:None
# sample_async:-1
# remote_worker_envs:False
# remote_env_batch_wait_ms:0
# enable_tf1_exec_eagerly:False
# sample_collector:<class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>
# preprocessor_pref:deepmind
# observation_filter:NoFilter
# update_worker_filter_stats:True
# use_worker_filter_stats:True
# gamma:0.99
# lr:0.001
# grad_clip:None
# grad_clip_by:global_norm
# train_batch_size:10000
# model:{'_disable_preprocessor_api': False, '_disable_action_flattening': False, 'fcnet_hiddens': [256, 256], 'fcnet_activation': 'tanh', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'framestack': True, 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': 'mine', 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'encoder_latent_dim': None, 'always_check_shapes': False, 'lstm_use_prev_action_reward': -1, '_use_default_native_models': -1}
# optimizer:{}
# max_requests_in_flight_per_sampler_worker:2
# _learner_class:None
# explore:True
# exploration_config:{'type': 'StochasticSampling'}
# algorithm_config_overrides_per_module:{}
# policy_map_capacity:100
# policy_mapping_fn:<function policy_mapping_fn at 0x7d06fb2d2b90>
# policies_to_train:None
# policy_states_are_swappable:False
# observation_fn:None
# count_steps_by:env_steps
# input_config:{}
# actions_in_input_normalized:False
# postprocess_inputs:False
# shuffle_buffer_size:0
# output:None
# output_config:{}
# output_compress_columns:['obs', 'new_obs']
# output_max_file_size:67108864
# offline_sampling:False
# evaluation_interval:None
# evaluation_duration:10
# evaluation_duration_unit:episodes
# evaluation_sample_timeout_s:180.0
# evaluation_parallel_to_training:False
# evaluation_config:None
# off_policy_estimation_methods:{}
# ope_split_batch_by_episode:True
# evaluation_num_workers:0
# always_attach_evaluation_results:False
# enable_async_evaluation:False
# in_evaluation:False
# sync_filters_on_rollout_workers_timeout_s:60.0
# keep_per_episode_custom_metrics:False
# metrics_episode_collection_timeout_s:60.0
# metrics_num_episodes_for_smoothing:100
# min_time_s_per_iteration:None
# min_train_timesteps_per_iteration:0
# min_sample_timesteps_per_iteration:0
# export_native_model_files:True
# checkpoint_trainable_policies_only:False
# logger_creator:None
# logger_config:None
# log_level:WARN
# log_sys_usage:True
# fake_sampler:False
# seed:None
# ignore_worker_failures:False
# recreate_failed_workers:False
# max_num_worker_restarts:1000
# delay_between_worker_restarts_s:60.0
# restart_failed_sub_environments:False
# num_consecutive_worker_failures_tolerance:100
# worker_health_probe_timeout_s:60
# worker_restore_timeout_s:1800
# _rl_module_spec:None
# _AlgorithmConfig__prior_exploration_config:None
# _enable_new_api_stack:False
# _tf_policy_handles_more_than_one_loss:False
# _disable_preprocessor_api:False
# _disable_action_flattening:False
# _disable_execution_plan_api:True
# _disable_initialize_loss_from_dummy_batch:False
# simple_optimizer:-1
# policy_map_cache:-1
# worker_cls:-1
# synchronize_filters:-1
# replay_sequence_length:None
# lr_schedule:None
# use_critic:True
# use_gae:True
# use_kl_loss:True
# kl_coeff:0.2
# kl_target:0.01
# sgd_minibatch_size:512
# num_sgd_iter:30
# shuffle_sequences:True
# vf_loss_coeff:1.0
# entropy_coeff:0
# entropy_coeff_schedule:None
# clip_param:0.2
# vf_clip_param:10.0
# vf_share_layers:-1
# lambda:0.95
# input:sampler
# policies:{'policy_initializer': (None, Box(-inf, inf, (17,), float32), Dict('element_1': MultiDiscrete([3 5])), {})}
# callbacks:<class 'ray.rllib.algorithms.callbacks.DefaultCallbacks'>
# create_env_on_driver:False
# custom_eval_function:None
# framework:torch
# num_cpus_for_driver:1
# num_workers:2

# %%
algo=config.build()
# Out:
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py:483: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-01-29 11:19:51,204	INFO worker.py:1724 -- Started a local Ray instance.
# (pid=2286) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
# (pid=2286)   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# (pid=2286) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=2286)   declare_namespace(pkg)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# (pid=2286) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=2286)   declare_namespace(pkg)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# (pid=2286) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=2286)   declare_namespace(pkg)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# (pid=2286) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=2286)   declare_namespace(pkg)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/flax/configurations.py:42: DeprecationWarning: jax.config.define_bool_state is deprecated. Please use other libraries for configuration instead.
# (pid=2286)   return jax_config.define_bool_state('flax_' + name, default, help)
# (pid=2286) /usr/local/lib/python3.10/dist-packages/flax/linen/activation.py:36: DeprecationWarning: jax.nn.normalize is deprecated. Use jax.nn.standardize instead.
# (pid=2286)   from jax.nn import normalize
# (pid=2286) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=2286)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=2286) [UnityMemory] Configuration Parameters - Can be set up in boot.config
# (RolloutWorker pid=2286)     "memorysetup-bucket-allocator-granularity=16"
# (RolloutWorker pid=2286)     "memorysetup-bucket-allocator-bucket-count=8"
# (RolloutWorker pid=2286)     "memorysetup-bucket-allocator-block-size=4194304"
# (RolloutWorker pid=2286)     "memorysetup-bucket-allocator-block-count=1"
# (RolloutWorker pid=2286)     "memorysetup-main-allocator-block-size=16777216"
# (RolloutWorker pid=2286)     "memorysetup-thread-allocator-block-size=16777216"
# (RolloutWorker pid=2286)     "memorysetup-gfx-main-allocator-block-size=16777216"
# (RolloutWorker pid=2286)     "memorysetup-gfx-thread-allocator-block-size=16777216"
# (RolloutWorker pid=2286)     "memorysetup-cache-allocator-block-size=4194304"
# (RolloutWorker pid=2286)     "memorysetup-typetree-allocator-block-size=2097152"
# (RolloutWorker pid=2286)     "memorysetup-profiler-bucket-allocator-granularity=16"
# (RolloutWorker pid=2286)     "memorysetup-profiler-bucket-allocator-bucket-count=8"
# (RolloutWorker pid=2286)     "memorysetup-profiler-bucket-allocator-block-size=4194304"
# (RolloutWorker pid=2286)     "memorysetup-profiler-bucket-allocator-block-count=1"
# (RolloutWorker pid=2286)     "memorysetup-profiler-allocator-block-size=16777216"
# (RolloutWorker pid=2286)     "memorysetup-profiler-editor-allocator-block-size=1048576"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-main=4194304"
# (RolloutWorker pid=2286)     "memorysetup-job-temp-allocator-block-size=2097152"
# (RolloutWorker pid=2286)     "memorysetup-job-temp-allocator-block-size-background=1048576"
# (RolloutWorker pid=2286)     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
# (RolloutWorker pid=2286)     "memorysetup-allocator-temp-initial-block-size-main=262144"
# (RolloutWorker pid=2286)     "memorysetup-allocator-temp-initial-block-size-worker=262144"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-background-worker=32768"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-job-worker=262144"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-preload-manager=262144"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-audio-worker=65536"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-cloud-worker=32768"
# (RolloutWorker pid=2286)     "memorysetup-temp-allocator-size-gfx=262144"
# (RolloutWorker pid=2286) Mono path[0] = '/content/Tile-Based-Level-Design/unity_built_linux/my_game_Data/Managed'
# (RolloutWorker pid=2286) Mono config path = '/content/Tile-Based-Level-Design/unity_built_linux/my_game_Data/MonoBleedingEdge/etc'
# (RolloutWorker pid=2286) Preloaded 'lib_burst_generated.so'
# (RolloutWorker pid=2286) Preloaded 'libgrpc_csharp_ext.x64.so'
# (RolloutWorker pid=2286) Found 1 interfaces on host : 0) 172.28.0.12
# (RolloutWorker pid=2286) Player connection [132000872468352] Multi-casting "[IP] 172.28.0.12 [Port] 55000 [Flags] 2 [Guid] 340674628 [EditorId] 3424980688 [Version] 1048832 [Id] LinuxPlayer(13,172.28.0.12) [Debug] 0 [PackageName] LinuxPlayer [ProjectName] RLUnity" to [225.0.0.222:54997]...
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) [Physics::Module] Initialized MultithreadedJobDispatcher with 1 workers.
# (RolloutWorker pid=2286) PlayerPrefs - Creating folder: /root/.config/unity3d/DefaultCompany
# (RolloutWorker pid=2286) PlayerPrefs - Creating folder: /root/.config/unity3d/DefaultCompany/RLUnity
# (RolloutWorker pid=2286) Unable to load player prefs
# (RolloutWorker pid=2286) Initialize engine version: 2022.3.15f1 (b58023a2b463)
# (RolloutWorker pid=2286) [Subsystems] Discovering subsystems at path /content/Tile-Based-Level-Design/unity_built_linux/my_game_Data/UnitySubsystems
# (RolloutWorker pid=2286) Forcing GfxDevice: Null
# (RolloutWorker pid=2286) GfxDevice: creating device client; threaded=0; jobified=0
# (RolloutWorker pid=2286) NullGfxDevice:
# (RolloutWorker pid=2286)     Version:  NULL 1.0 [1.0]
# (RolloutWorker pid=2286)     Renderer: Null Device
# (RolloutWorker pid=2286)     Vendor:   Unity Technologies
# (RolloutWorker pid=2286) error: XDG_RUNTIME_DIR not set in the environment.
# (RolloutWorker pid=2286) FMOD failed to initialize the output device.: "Error initializing output device. " (60)
# (RolloutWorker pid=2286) Forced to initialize FMOD to to the device driver's system output rate 48000, this may impact performance and/or give inconsistent experiences compared to selected sample rate 48000
# (RolloutWorker pid=2286) FMOD failed to initialize the output device.: "Error initializing output device. " (60)
# (RolloutWorker pid=2286) FMOD initialized on nosound output
# (RolloutWorker pid=2286) Begin MonoManager ReloadAssembly
# (RolloutWorker pid=2286) ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# (RolloutWorker pid=2286) ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# (RolloutWorker pid=2286) ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# (RolloutWorker pid=2286) ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# (RolloutWorker pid=2286) - Loaded All Assemblies, in  0.166 seconds
# (RolloutWorker pid=2286) - Finished resetting the current domain, in  0.003 seconds
# (RolloutWorker pid=2286) ERROR: Shader Sprites/Default shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# (RolloutWorker pid=2286) ERROR: Shader Sprites/Mask shader is not supported on this GPU (none of subshaders/fallbacks are suitable)
# (RolloutWorker pid=2286) UnloadTime: 1.109157 ms
# (RolloutWorker pid=2286) Registered Communicator in Agent.
# (RolloutWorker pid=2286) UnityEngine.StackTraceUtility:ExtractStackTrace () (at /home/bokken/build/output/unity/unity/Runtime/Export/Scripting/StackTrace.cs:37)
# (RolloutWorker pid=2286) UnityEngine.DebugLogHandler:LogFormat (UnityEngine.LogType,UnityEngine.Object,string,object[])
# (RolloutWorker pid=2286) UnityEngine.Logger:Log (UnityEngine.LogType,object)
# (RolloutWorker pid=2286) UnityEngine.Debug:Log (object)
# (RolloutWorker pid=2286) Unity.MLAgents.Agent:Awake () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs:373)
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) (Filename: ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs Line: 373)
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) Created UnityEnvironment for port 5005
# (RolloutWorker pid=2286)   unity_communicator_version = StrictVersion(unity_com_ver)
# (RolloutWorker pid=2286) 2024-01-29 11:20:11,036	WARNING env.py:56 -- Skipping env checking for this experiment
# (pid=2289) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
# (pid=2289)   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# (pid=2289) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# (pid=2289) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (pid=2289)   declare_namespace(pkg) [repeated 4x across cluster]
# (pid=2289) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# (pid=2289) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# (pid=2289) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# (pid=2289) /usr/local/lib/python3.10/dist-packages/flax/configurations.py:42: DeprecationWarning: jax.config.define_bool_state is deprecated. Please use other libraries for configuration instead.
# (pid=2289)   return jax_config.define_bool_state('flax_' + name, default, help)
# (pid=2289) /usr/local/lib/python3.10/dist-packages/flax/linen/activation.py:36: DeprecationWarning: jax.nn.normalize is deprecated. Use jax.nn.standardize instead.
# (pid=2289)   from jax.nn import normalize
# (RolloutWorker pid=2286) /usr/local/lib/python3.10/dist-packages/mlagents_envs/environment.py:94: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead. [repeated 2x across cluster]
# (pid=2289)   if (distutils.version.LooseVersion(tf.__version__) <
# 2024-01-29 11:20:17,712	INFO trainable.py:164 -- Trainable.setup took 29.990 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2024-01-29 11:20:17,717	WARNING util.py:62 -- Install gputil for GPU system monitoring.

# %%
#%%capture
results=[]
for i in range(50):
            result = algo.train()
            results.append(result)
            #pprint(results[i])
            print("traning iteration number {} finished".format(i))
            print("the min reward for result{} is: {}".format(i,results[i]['episode_reward_min']))
            print("the mean reward for result{} is: {}".format(i,results[i]['episode_reward_mean']))
            print("the max reward for result{} is: {} ".format(i,results[i]['episode_reward_max']))


            print("\n\n\n")





            if (
                result['timesteps_total'] >= 10000000000
                or result["episode_reward_mean"] >= 10000000000
                or result["episodes_total"]>=100000000000
            ):
                break
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7)
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7)
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 10x across cluster]
# 2024-01-29 11:23:39,514	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# WARNING:tensorboardX.x2num:NaN or Inf found in input tensor.
# WARNING:tensorboardX.x2num:NaN or Inf found in input tensor.
# traning iteration number 0 finished
# the min reward for result0 is: -5.0
# the mean reward for result0 is: -1.58
# the max reward for result0 is: 1.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 6x across cluster]
# traning iteration number 1 finished
# the min reward for result1 is: -5.0
# the mean reward for result1 is: -1.55
# the max reward for result1 is: 1.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 20x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 28x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 4x across cluster]
# traning iteration number 2 finished
# the min reward for result2 is: -5.0
# the mean reward for result2 is: -1.5841584158415842
# the max reward for result2 is: 2.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 18x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 6x across cluster]
# traning iteration number 3 finished
# the min reward for result3 is: -5.0
# the mean reward for result3 is: -1.2156862745098038
# the max reward for result3 is: 2.0
#
#
#
#
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 11x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 20x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 20x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 14x across cluster]
# traning iteration number 4 finished
# the min reward for result4 is: -4.0
# the mean reward for result4 is: -1.495049504950495
# the max reward for result4 is: 2.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 20x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 44x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 36x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 38x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 54x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 24x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 18x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 54x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 30x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 10x across cluster]
# traning iteration number 5 finished
# the min reward for result5 is: -5.0
# the mean reward for result5 is: -1.68
# the max reward for result5 is: 1.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 42x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 34x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 18x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 16x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 28x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 28x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 38x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 28x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 32x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 32x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 20x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 18x across cluster]
# traning iteration number 6 finished
# the min reward for result6 is: -5.0
# the mean reward for result6 is: -1.4095238095238096
# the max reward for result6 is: 5.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 30x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 6x across cluster]
# (RolloutWorker pid=2286) UnityEngine.StackTraceUtility:ExtractStackTrace () (at /home/bokken/build/output/unity/unity/Runtime/Export/Scripting/StackTrace.cs:37)
# (RolloutWorker pid=2286) UnityEngine.Transform:get_position ()
# (RolloutWorker pid=2286) LearnerInstantiator:CollectObservations (Unity.MLAgents.Sensors.VectorSensor) (at C:/my/code/unity/Tile-Based-level-Design/Assets/script/LearnerInstantiator.cs:227)
# (RolloutWorker pid=2286) Unity.MLAgents.Agent:SendInfoToBrain () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs:1112)
# (RolloutWorker pid=2286) Unity.MLAgents.Agent:SendInfo () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs:1368)
# (RolloutWorker pid=2286) Unity.MLAgents.Academy:EnvironmentStep () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Academy.cs:592)
# (RolloutWorker pid=2286) Unity.MLAgents.AcademyFixedUpdateStepper:FixedUpdate () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Academy.cs:43)
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) [./Runtime/Allocator/ThreadsafeLinearAllocator.cpp line 248]
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) UnityEngine.StackTraceUtility:ExtractStackTrace () (at /home/bokken/build/output/unity/unity/Runtime/Export/Scripting/StackTrace.cs:37)
# (RolloutWorker pid=2286) UnityEngine.Transform:get_position ()
# (RolloutWorker pid=2286) LearnerInstantiator:CollectObservations (Unity.MLAgents.Sensors.VectorSensor) (at C:/my/code/unity/Tile-Based-level-Design/Assets/script/LearnerInstantiator.cs:227)
# (RolloutWorker pid=2286) Unity.MLAgents.Agent:SendInfoToBrain () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs:1112)
# (RolloutWorker pid=2286) Unity.MLAgents.Agent:SendInfo () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Agent.cs:1368)
# (RolloutWorker pid=2286) Unity.MLAgents.Academy:EnvironmentStep () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Academy.cs:592)
# (RolloutWorker pid=2286) Unity.MLAgents.AcademyFixedUpdateStepper:FixedUpdate () (at ./ml-agents-release_20/com.unity.ml-agents/Runtime/Academy.cs:43)
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2286) [./Runtime/Allocator/ThreadsafeLinearAllocator.cpp line 248]
# (RolloutWorker pid=2286)
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 26x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 54x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 32x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 52x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 42x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 16x across cluster]
# traning iteration number 7 finished
# the min reward for result7 is: -5.0
# the mean reward for result7 is: -1.3786407766990292
# the max reward for result7 is: 3.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 16x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 20x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 48x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 26x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 36x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 30x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 28x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 32x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 34x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 28x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 42x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 28x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 14x across cluster]
# traning iteration number 8 finished
# the min reward for result8 is: -6.0
# the mean reward for result8 is: -1.0192307692307692
# the max reward for result8 is: 3.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 36x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 32x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 34x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 42x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 42x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 2x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 32x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 34x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 26x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 16x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 16x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 36x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 30x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 52x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 36x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: JobTempAlloc has allocations that are more than the maximum lifespan of 4 frames old - this is not allowed and likely a leak
# (RolloutWorker pid=2289) To Debug, run app with -diag-job-temp-memory-leak-validation cmd line argument. This will output the callstacks of the leaked allocations.
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 18x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 4x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 48x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 12x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 10x across cluster]
# traning iteration number 9 finished
# the min reward for result9 is: -5.0
# the mean reward for result9 is: -0.9038461538461539
# the max reward for result9 is: 6.0
#
#
#
#
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 46x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 20x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 24x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 36x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 18x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 6x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 28x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 64x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 14x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 14x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 8x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 8x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 30x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 24x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 44x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 6x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 10x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 4x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 12x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 70x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 26x across cluster]
# traning iteration number 10 finished
# the min reward for result10 is: -4.0
# the mean reward for result10 is: -0.7777777777777778
# the max reward for result10 is: 4.0
#
#
#
#
# ...
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 110x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 44x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 62x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 82x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 64x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 106x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 92x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 78x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 100x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 72x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 38x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 34x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 76x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 106x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 76x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 78x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 60x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 58x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 64x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 40x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 44x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 30x across cluster]
# traning iteration number 47 finished
# the min reward for result47 is: -4.0
# the mean reward for result47 is: 2.4875
# the max reward for result47 is: 7.0
#
#
#
#
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 10x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 62x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 74x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 126x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 114x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 42x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 86x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 48x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 88x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 68x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 48x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 88x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 66x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 86x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 126x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 36x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 8) [repeated 60x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 116x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 94x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 74x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 70x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 108x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 60x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 50x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 160x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 46x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 86x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 68x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 84x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 102x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 88x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 82x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 22x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 68x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 98x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 80x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 64x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 80x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 82x across cluster]
# traning iteration number 48 finished
# the min reward for result48 is: -5.0
# the mean reward for result48 is: 2.2
# the max reward for result48 is: 7.0
#
#
#
#
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 24x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 56x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 106x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 44x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 10) [repeated 68x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 90x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 30x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 98x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 48x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 86x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 70x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 92x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 80x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 72x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 15) [repeated 80x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 64x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 22x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 76x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 134x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 98x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 13) [repeated 78x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 120x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 102x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 42x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 58x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 90x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 134x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 9) [repeated 92x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 11) [repeated 118x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 76x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 80x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 7) [repeated 84x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 42x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 14) [repeated 72x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 114x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 5) [repeated 82x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 54x across cluster]
# (RolloutWorker pid=2286) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 6) [repeated 101x across cluster]
# (RolloutWorker pid=2289) Internal: deleting an allocation that is older than its permitted lifetime of 4 frames (age = 12) [repeated 44x across cluster]
# traning iteration number 49 finished
# the min reward for result49 is: -5.0
# the mean reward for result49 is: 2.5306122448979593
# the max reward for result49 is: 7.0

# %%
def export_algo():
  # save and print the path of the checkpoint
  save_result = algo.save()
  path_to_checkpoint = save_result.checkpoint.path
  print(
      "An Algorithm checkpoint has been created inside directory: "
      f"'{path_to_checkpoint}'."
  )
  start_time = time.time()
  while not os.path.exists(path_to_checkpoint):
      if time.time() - start_time >= 20:
          print("time for build algo out")
          break
      time.sleep(1)
  print("algo  builded at {}".format(path_to_checkpoint) )
  return path_to_checkpoint
export_algo()
# Out:
# An Algorithm checkpoint has been created inside directory: '/tmp/tmpcwc68wt0'.
# algo  builded at /tmp/tmpcwc68wt0
# '/tmp/tmpcwc68wt0'

# %%
from google.colab import files
def download_algo(path_to_algo):
  # !zip -r {path_to_algo}.zip {path_to_algo}
  start_time = time.time()
  while not os.path.exists(path_to_algo):
      if time.time() - start_time >= 20:
          print("time for zipping algo out")
          break
      time.sleep(1)
  print("algo  zipped at {}".format(path_to_algo) )
  path_to_algo=path_to_algo+".zip"
  files.download(path_to_algo)
download_algo("/tmp/tmpcwc68wt0")
# Out:
#   adding: tmp/tmpcwc68wt0/ (stored 0%)
#   adding: tmp/tmpcwc68wt0/algorithm_state.pkl (deflated 55%)
#   adding: tmp/tmpcwc68wt0/policies/ (stored 0%)
#   adding: tmp/tmpcwc68wt0/policies/policy_initializer/ (stored 0%)
#   adding: tmp/tmpcwc68wt0/policies/policy_initializer/model/ (stored 0%)
#   adding: tmp/tmpcwc68wt0/policies/policy_initializer/model/model.pt (deflated 29%)
#   adding: tmp/tmpcwc68wt0/policies/policy_initializer/policy_state.pkl (deflated 29%)
#   adding: tmp/tmpcwc68wt0/policies/policy_initializer/rllib_checkpoint.json (deflated 27%)
#   adding: tmp/tmpcwc68wt0/rllib_checkpoint.json (deflated 30%)
# algo  zipped at /tmp/tmpcwc68wt0

# %%
#%%capture
results=[]
for i in range(10):
            result = algo.train()
            results.append(result)
            #pprint(results[i])
            print("traning iteration number {} finished".format(i))
            print("the min reward for result{} is: {}".format(i,results[i]['episode_reward_min']))
            print("the mean reward for result{} is: {}".format(i,results[i]['episode_reward_mean']))
            print("the max reward for result{} is: {} ".format(i,results[i]['episode_reward_max']))


            print("\n\n\n")





            if (
                result['timesteps_total'] >= 10000000000
                or result["episode_reward_mean"] >= 10000000000
                or result["episodes_total"]>=100000000000
            ):
                break

# %% [markdown]
# # load and test algorithm

# %%
def load_algo(path_to_checkpoint):
   algo = Algorithm.from_checkpoint(path_to_checkpoint)
   return algo

algo=load_algo(filename_algo)
# Out:
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py:483: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /usr/local/lib/python3.10/dist-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-01-29 08:48:43,688	INFO worker.py:1724 -- Started a local Ray instance.
# (pid=1769) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
# (pid=1769)   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# (pid=1769) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=1769)   declare_namespace(pkg)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# (pid=1769) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=1769)   declare_namespace(pkg)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# (pid=1769) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=1769)   declare_namespace(pkg)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# (pid=1769) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# (pid=1769)   declare_namespace(pkg)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/flax/configurations.py:42: DeprecationWarning: jax.config.define_bool_state is deprecated. Please use other libraries for configuration instead.
# (pid=1769)   return jax_config.define_bool_state('flax_' + name, default, help)
# (pid=1769) /usr/local/lib/python3.10/dist-packages/flax/linen/activation.py:36: DeprecationWarning: jax.nn.normalize is deprecated. Use jax.nn.standardize instead.
# (pid=1769)   from jax.nn import normalize
# (pid=1769) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=1769)   if (distutils.version.LooseVersion(tf.__version__) <
# (RolloutWorker pid=1769) [UnityMemory] Configuration Parameters - Can be set up in boot.config
# (RolloutWorker pid=1769)     "memorysetup-bucket-allocator-granularity=16"
# (RolloutWorker pid=1769)     "memorysetup-bucket-allocator-bucket-count=8"
# (RolloutWorker pid=1769)     "memorysetup-bucket-allocator-block-size=4194304"
# (RolloutWorker pid=1769)     "memorysetup-bucket-allocator-block-count=1"
# (RolloutWorker pid=1769)     "memorysetup-main-allocator-block-size=16777216"
# (RolloutWorker pid=1769)     "memorysetup-thread-allocator-block-size=16777216"
# (RolloutWorker pid=1769)     "memorysetup-gfx-main-allocator-block-size=16777216"
# (RolloutWorker pid=1769)     "memorysetup-gfx-thread-allocator-block-size=16777216"
# (RolloutWorker pid=1769)     "memorysetup-cache-allocator-block-size=4194304"
# (RolloutWorker pid=1769)     "memorysetup-typetree-allocator-block-size=2097152"
# (RolloutWorker pid=1769)     "memorysetup-profiler-bucket-allocator-granularity=16"
# (RolloutWorker pid=1769)     "memorysetup-profiler-bucket-allocator-bucket-count=8"
# (RolloutWorker pid=1769)     "memorysetup-profiler-bucket-allocator-block-size=4194304"
# (RolloutWorker pid=1769)     "memorysetup-profiler-bucket-allocator-block-count=1"
# (RolloutWorker pid=1769)     "memorysetup-profiler-allocator-block-size=16777216"
# (RolloutWorker pid=1769)     "memorysetup-profiler-editor-allocator-block-size=1048576"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-main=4194304"
# (RolloutWorker pid=1769)     "memorysetup-job-temp-allocator-block-size=2097152"
# (RolloutWorker pid=1769)     "memorysetup-job-temp-allocator-block-size-background=1048576"
# (RolloutWorker pid=1769)     "memorysetup-job-temp-allocator-reduction-small-platforms=262144"
# (RolloutWorker pid=1769)     "memorysetup-allocator-temp-initial-block-size-main=262144"
# (RolloutWorker pid=1769)     "memorysetup-allocator-temp-initial-block-size-worker=262144"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-background-worker=32768"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-job-worker=262144"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-preload-manager=262144"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-nav-mesh-worker=65536"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-audio-worker=65536"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-cloud-worker=32768"
# (RolloutWorker pid=1769)     "memorysetup-temp-allocator-size-gfx=262144"
# (RolloutWorker pid=1769) error: XDG_RUNTIME_DIR not set in the environment.
# (pid=1768) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
# (pid=1768)   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# (pid=1768) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# (pid=1768) Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (pid=1768)   declare_namespace(pkg) [repeated 4x across cluster]
# (pid=1768) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# (pid=1768) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('mpl_toolkits')`.
# (pid=1768) /usr/local/lib/python3.10/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# (pid=1768) /usr/local/lib/python3.10/dist-packages/flax/configurations.py:42: DeprecationWarning: jax.config.define_bool_state is deprecated. Please use other libraries for configuration instead.
# (pid=1768)   return jax_config.define_bool_state('flax_' + name, default, help)
# (pid=1768) /usr/local/lib/python3.10/dist-packages/flax/linen/activation.py:36: DeprecationWarning: jax.nn.normalize is deprecated. Use jax.nn.standardize instead.
# (pid=1768)   from jax.nn import normalize
# (pid=1768) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=1768)   if (distutils.version.LooseVersion(tf.__version__) <
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-25f0b87b8d01> in <cell line: 5>()
#       3    return algo
#       4
# ----> 5 algo=load_algo(filename_algo)
#
# <ipython-input-12-25f0b87b8d01> in load_algo(path_to_checkpoint)
#       1 def load_algo(path_to_checkpoint):
# ----> 2    algo = Algorithm.from_checkpoint(path_to_checkpoint)
#       3    return algo
#       4
#       5 algo=load_algo(filename_algo)
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py in from_checkpoint(checkpoint, policy_ids, policy_mapping_fn, policies_to_train)
#     342         )
#     343
# --> 344         return Algorithm.from_state(state)
#     345
#     346     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py in from_state(state)
#     370         if not config:
#     371             raise ValueError("No `config` found in given Algorithm state!")
# --> 372         new_algo = algorithm_class(config=config)
#     373         # Set the new algo's state.
#     374         new_algo.__setstate__(state)
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py in __init__(self, config, env, logger_creator, **kwargs)
#     514         }
#     515
# --> 516         super().__init__(
#     517             config=config,
#     518             logger_creator=logger_creator,
#
# /usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py in __init__(self, config, logger_creator, storage)
#     159         self._open_logfiles(stdout_file, stderr_file)
#     160
# --> 161         self.setup(copy.deepcopy(self.config))
#     162         setup_time = time.time() - self._start_time
#     163         if setup_time > SETUP_TIME_THRESHOLD:
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/algorithms/algorithm.py in setup(self, config)
#     636         if _init is False:
#     637             # Create a set of env runner actors via a WorkerSet.
# --> 638             self.workers = WorkerSet(
#     639                 env_creator=self.env_creator,
#     640                 validate_env=self.validate_env,
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/evaluation/worker_set.py in __init__(self, env_creator, validate_env, default_policy_class, config, num_workers, local_worker, logdir, _setup)
#     157         if _setup:
#     158             try:
# --> 159                 self._setup(
#     160                     validate_env=validate_env,
#     161                     config=config,
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/evaluation/worker_set.py in _setup(self, validate_env, config, num_workers, local_worker)
#     227
#     228         # Create a number of @ray.remote workers.
# --> 229         self.add_workers(
#     230             num_workers,
#     231             validate=config.validate_workers_after_construction,
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/evaluation/worker_set.py in add_workers(self, num_workers, validate)
#     608         # and are "up and running". Establish initial states.
#     609         if validate:
# --> 610             for result in self.__worker_manager.foreach_actor(
#     611                 lambda w: w.assert_healthy()
#     612             ):
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/utils/actor_manager.py in foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     596         )
#     597
# --> 598         _, remote_results = self.__fetch_result(
#     599             remote_actor_ids=remote_actor_ids,
#     600             remote_calls=remote_calls,
#
# /usr/local/lib/python3.10/dist-packages/ray/rllib/utils/actor_manager.py in __fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     464             return [], RemoteCallResults()
#     465
# --> 466         ready, _ = ray.wait(
#     467             remote_calls,
#     468             num_returns=len(remote_calls),
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py in auto_init_wrapper(*args, **kwargs)
#      20     def auto_init_wrapper(*args, **kwargs):
#      21         auto_init_ray()
# ---> 22         return fn(*args, **kwargs)
#      23
#      24     return auto_init_wrapper
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py in wrapper(*args, **kwargs)
#     101             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103         return func(*args, **kwargs)
#     104
#     105     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/ray/_private/worker.py in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2845         timeout = timeout if timeout is not None else 10**6
#    2846         timeout_milliseconds = int(timeout * 1000)
# -> 2847         ready_ids, remaining_ids = worker.core_worker.wait(
#    2848             ray_waitables,
#    2849             num_returns,
#
# python/ray/_raylet.pyx in ray._raylet.CoreWorker.wait()
#
# python/ray/_raylet.pyx in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
env =Unity3DEnv(file_name=filename_linux ,
                              episode_horizon=200  ,
                                no_graphics=False,
               )

# %%
initial_state = algo.get_policy("policy_initializer").get_initial_state()
terminateds ={}
truncateds={}
num_win=0
num_loss=0


for i in range(30):
    obs,info=env.reset()
    terminateds['__all__'] = truncateds['__all__'] = False
    episode_reward=0
    timestep=0


    while not  terminateds['__all__'] and not  truncateds['__all__'] :
        action= algo.compute_single_action(observation=obs['instantiator Behaviour?team=0_0'] , state=initial_state , policy_id= "policy_initializer")
        action_dict={"instantiator Behaviour?team=0_0":action}
        obs, rewards, terminateds, truncateds, infos=env.step(action_dict)
        #print(rewards)
        episode_reward += rewards["instantiator Behaviour?team=0_0"]
        timestep +=1
    print("total time step is {}".format(timestep))
    print("total episode_reward is {}".format(episode_reward))
    if  terminateds['__all__'] :
        print("reach the goal "+"\n")
        num_win=num_win+1

    if  truncateds['__all__']:
        print("not reach"+"\n")
        num_loss=num_loss+1

print("number of win is {}".format(num_win))
print("number of loss is {}".format(num_loss))
